# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
a = np.load('HuBMAP_512/0486052bb_133.png.npz')
b = a['image']
imgplot = plt.imshow(b)
plt.show()
np.ptp(b)
# Out:
# 1.0

# %%
b = a['label']
imgplot = plt.imshow(b)
plt.show()
np.ptp(b)
# Out:
# 1
